# %%
from IPython.core.display import os
from google.colab import userdata
os.environ['GEMINI_API_KEY']=userdata.get('GEMINI_API_KEY')
os.environ['ANTHROPIC_API_KEY']=userdata.get('ANTHROPIC_API_KEY')

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="claude-sonnet-4-6")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content="The Moon doesn't have a capital city. It has no permanent human settlements, government, or political organization. It's a natural satellite with no indigenous population.\n\nThere are named locations like **Mare Tranquillitatis** (Sea of Tranquility), where Apollo 11 landed, but nothing resembling a capital. Would you like to know something else about the Moon?", additional_kwargs={}, response_metadata={'id': 'msg_01EUqdFHWJNwDrcxhMo6g5L4', 'container': None, 'model': 'claude-sonnet-4-6', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'global', 'input_tokens': 15, 'output_tokens': 83, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-6', 'model_provider': 'anthropic'}, id='lc_run--019df0b6-4194-77a0-86ba-7898c2a69937-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 83, 'total_tokens': 98, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})

# %%
print(response.content)
# Out:
# The Moon doesn't have a capital city. It has no permanent human settlements, government, or political organization. It's a natural satellite with no indigenous population.
#
# There are named locations like **Mare Tranquillitatis** (Sea of Tranquility), where Apollo 11 landed, but nothing resembling a capital. Would you like to know something else about the Moon?

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'container': None,
#  'id': 'msg_01EUqdFHWJNwDrcxhMo6g5L4',
#  'model': 'claude-sonnet-4-6',
#  'model_name': 'claude-sonnet-4-6',
#  'model_provider': 'anthropic',
#  'stop_details': None,
#  'stop_reason': 'end_turn',
#  'stop_sequence': None,
#  'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0,
#                               'ephemeral_5m_input_tokens': 0},
#            'cache_creation_input_tokens': 0,
#            'cache_read_input_tokens': 0,
#            'inference_geo': 'global',
#            'input_tokens': 15,
#            'output_tokens': 83,
#            'server_tool_use': None,
#            'service_tier': 'standard'}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="claude-haiku-4-5",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or political entity. It's Earth's natural satellite.
#
# If you're asking this as a playful question, you might be thinking of science fiction scenarios! But in reality, the Moon has no government, cities, or capitals.
#
# Is there something specific about the Moon you're curious about?

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-haiku-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or political entity. It's Earth's natural satellite.
#
# If you're asking in a playful way, or if you're thinking of a fictional setting, I'd be happy to help with that context! Are you thinking of a science fiction story or a creative project?

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon does not have a capital city.
#
# This is because:
# *   **It's not a country:** The Moon is a celestial body, not a sovereign nation.
# *   **No government:** There is no single government or political entity that controls the entire Moon (or any part of it, legally speaking, as per the Outer Space Treaty).
# *   **No permanent settlements:** While there have been human visitors and temporary research bases, there are no permanent cities or large human populations that would require a capital.
#
# So, the concept of a 'capital' doesn't apply to the Moon.

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='26e230e2-00ef-4f39-84b9-2a6be7864d2d'),
#               AIMessage(content="The Moon doesn't have a capital because it's not a country or inhabited territory. It's Earth's natural satellite with no permanent population or government.\n\nIf you're asking about proposed lunar bases or settlements, none exist yet, though several countries and private companies have plans for future lunar installations.", additional_kwargs={}, response_metadata={'id': 'msg_01NKX675SbSHi945r6D64mSB', 'container': None, 'model': 'claude-sonnet-4-5-20250929', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'not_available', 'input_tokens': 15, 'output_tokens': 62, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-5-20250929', 'model_provider': 'anthropic'}, id='lc_run--019df0bf-5651-7983-ba76-0eeac67e894e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 62, 'total_tokens': 77, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})]}

# %%
print(response['messages'][-1].content)
# Out:
# The Moon doesn't have a capital because it's not a country or inhabited territory. It's Earth's natural satellite with no permanent population or government.
#
# If you're asking about proposed lunar bases or settlements, none exist yet, though several countries and private companies have plans for future lunar installations.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='cf51ab1f-3736-4fd9-8796-2ef5054fd034'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='8fbf9c8e-244e-4537-8188-33749893aa2b', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='b6d9f188-224c-43cc-bded-865f01a20aea'),
#               AIMessage(content='I apologize for my previous response - that was incorrect. The Moon doesn\'t have a capital city. Luna City is a fictional location that appears in science fiction stories, books, and films.\n\nThe Moon has no permanent human settlements at all. While humans have visited the Moon during the Apollo missions (1969-1972), no one currently lives there, and there are no cities or capitals.\n\nThere are various fictional depictions of lunar cities in science fiction, with "Luna City" or similar names appearing in works by authors like Robert Heinlein and others, but these are imaginary, not real places.', additional_kwargs={}, response_metadata={'id': 'msg_01CcL6nhQJfQQ6oVRqfuEPwG', 'container': None, 'model': 'claude-sonnet-4-5-20250929', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'not_available', 'input_tokens': 39, 'output_tokens': 130, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-5-20250929', 'model_provider': 'anthropic'}, id='lc_run--019df0bf-fca4-7592-a11a-6df210cfa11e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 130, 'total_tokens': 169, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token

    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# # Luna City
#
# I should clarify that **Luna City is not a real place** - there is no capital city on the Moon. However, "Luna City" is a popular name in science fiction for imagined lunar settlements. Let me share some context:
#
# ## In Science Fiction
#
# **Luna City** (or variations like "Luna" or "Lunar City") appears frequently in sci-fi literature and media:
#
# - **Robert Heinlein's works** - particularly *The Moon is a Harsh Mistress* (1966), which features a lunar colony
# - **Various films and TV shows** depicting future Moon colonization
# - **Video games** set in space exploration scenarios
#
# These fictional versions typically include:
# - Pressurized habitat domes or underground facilities
# - Spaceports for Earth-Moon transit
# - Mining operations (often for helium-3 or rare minerals)
# - Research facilities
# - Varying degrees of political autonomy from Earth
#
# ## Reality
#
# Currently, the Moon has:
# - No permanent human settlements
# - No capital city or government
# - Only temporary visits by astronauts (last crewed landing: Apollo 17 in 1972)
#
# However, several nations and private companies are planning future lunar bases, so a "Luna City" might eventually exist!
#
# **Were you asking about a specific fictional Luna City from a book, game, or movie?** I'd be happy to discuss that particular version if you let me know which one!
